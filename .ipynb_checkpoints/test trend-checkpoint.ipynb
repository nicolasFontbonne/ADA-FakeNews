# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import re
import urllib
from urllib.request import Request, urlopen
import json
from wordcloud import WordCloud
from bs4 import BeautifulSoup
from PIL import Image
import datetime

# %%
liar = pd.read_csv('politifact_save.csv', delimiter=',',encoding='utf-8',parse_dates = [0])
liar['Date'] = liar['Date'].dt.to_period('M')
#liar = liar[["Date", "Label"]]

# %%
liar.head()
# Out:
#         Date        Label PoliticalParty
# 0 2018-12-01         True     Republican
# 1 2018-12-09    Half True           None
# 2 2018-12-08         True       Democrat
# 3 2018-12-09  Mostly True           None
# 4 2018-11-27    Half True       Democrat

# %%
liar.Label.unique()
# Out:
# array(['True', 'Half True', 'Mostly True', 'Full Flop', 'Mostly False',
#        'False', 'Pants on Fire', 'Half Flip', 'No Flip'], dtype=object)

# %%
test = liar.groupby(['Date','Label']).count()
test = test.unstack('Label')
test = test.fillna(0)
test = test[[('PoliticalParty', 'Full Flop'),('PoliticalParty', 'Half Flip'),('PoliticalParty', 'No Flip'),('PoliticalParty', 'Pants on Fire'),('PoliticalParty', 'False'),('PoliticalParty', 'Mostly False'),('PoliticalParty', 'Mostly True'),('PoliticalParty', 'True')]]
test = test[datetime.datetime(2015, 1, 1):]
test = test.div(test.sum(axis = 1),axis = 'index')
#test['False'] = test[[('ID', 'pants-fire'),('ID', 'false'),('ID', 'barely-true')]].sum(axis = 1)
test
# Out:
#            PoliticalParty                                            \
# Label           Full Flop Half Flip No Flip Pants on Fire     False
# Date
# 2015-02-01            NaN       NaN     NaN           NaN       NaN
# 2015-02-09            NaN       NaN     NaN           NaN       NaN
# 2015-02-16           0.00       0.0     0.0      1.000000  0.000000
# 2015-03-09           0.00       0.0     0.0      0.000000  1.000000
# 2015-03-10            NaN       NaN     NaN           NaN       NaN
# 2015-03-15           0.00       0.0     0.0      1.000000  0.000000
# 2015-03-16           0.00       0.0     0.0      0.000000  0.000000
# 2015-03-25           0.00       0.0     0.0      0.000000  0.000000
# 2015-03-27           0.00       0.0     0.0      0.000000  0.000000
# 2015-03-29           0.00       0.0     0.0      0.000000  0.000000
# 2015-03-31           0.00       0.0     0.0      0.000000  0.000000
# 2015-04-06           0.00       0.0     0.0      0.000000  0.000000
# ...
